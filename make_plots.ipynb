# %%
# %load_ext autoreload
# %autoreload 2

from plot import load_outputs, plot_final_loss_vs_lr, plot_tuned_curves
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 12
plt.rcParams['axes.linewidth'] = 1.5
plt.rc('text', usetex=False)
plt.rc('mathtext', fontset='cm')   # optional: use Computer Modern fontsplt.rc('legend', fontsize=10)

# %%
output_dir = "outputs/gpt-small/fineweb1B/baselines/"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# Sort outputs by the order of methods
outputs = sorted(outputs, key=lambda x: methods.index(x['name'].split('-lr-')[0]))

# 3) get a distinct qualitative colormap (tab20, Set3, or seaborn color_palette)
# Option A: matplotlib's tab20 (20 distinct colors)

base_colors = sns.color_palette("husl", len(methods))
colormap = {m: base_colors[i] for i, m in enumerate(methods)}

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="fineweb1B_baseline", val=True)
plt.show()

# %%
output_dir = "outputs/gpt-small/fineweb1B/baselines/"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

base_colors = sns.color_palette("husl", len(methods))
colormap = {m: base_colors[i] for i, m in enumerate(methods)}

plot_tuned_curves(outputs, colormap, outfilename="fineweb1B_baseline", val=False, wallclock=True)

# %%
output_dir = "outputs/gpt-small/fineweb1B/baselines/"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

base_colors = sns.color_palette("husl", len(methods))
colormap = {m: base_colors[i] for i, m in enumerate(methods)}

plot_tuned_curves(outputs, colormap, outfilename="fineweb1B_baseline", val=False, wallclock=False, num_epochs=1)

# %%
output_dir = "gptopt/outputs/finewebmini/finewebmini_best"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

plot_tuned_curves(outputs, colormap, outfilename="finewebmini", val=False, wallclock=True)

# %%
output_dir = "gptopt/outputs/finewebmini_best/"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# Sort outputs by the order of methods
outputs = sorted(outputs, key=lambda x: methods.index(x['name'].split('-lr-')[0]))

# 3) get a distinct qualitative colormap (tab20, Set3, or seaborn color_palette)
# Option A: matplotlib's tab20 (20 distinct colors)
base_colors = plt.get_cmap("tab20").colors  

# Option B: seaborn "hls" or "husl" palette (works for any number of categories)
# base_colors = sns.color_palette("husl", len(methods))

# 4) assign each method a color
colormap = {m: base_colors[i % len(base_colors)] for i, m in enumerate(methods)}

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-finewebmini-best", val=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 output_dir = "gptopt/outputs/finewebmini_best/"
# ----> 2 outputs = load_outputs(output_dir)
#       4 # 2) extract unique method names (before the "-lr-" suffix)
#       5 methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })
#
# File ~/GPT-opt/plot.py:21, in load_outputs(output_dir)
#      19 """Load all individual output files from a directory."""
#      20 outputs = []
# ---> 21 for file_name in os.listdir(output_dir):
#      22     if file_name.endswith(".json"):
#      23         file_path = os.path.join(output_dir, file_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gptopt/outputs/finewebmini_best/'

# %%
output_dir = "gptopt/outputs/dap-mom-ns-adam"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a distinct qualitative colormap (tab20, Set3, or seaborn color_palette)
# Option A: matplotlib's tab20 (20 distinct colors)
base_colors = plt.get_cmap("tab20").colors  

# Option B: seaborn "hls" or "husl" palette (works for any number of categories)
# base_colors = sns.color_palette("husl", len(methods))

# 4) assign each method a color
colormap = {m: base_colors[i % len(base_colors)] for i, m in enumerate(methods)}

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-mom-ns-adam", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/3dap-mom-ns-adam"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a distinct qualitative colormap (tab20, Set3, or seaborn color_palette)
# Option A: matplotlib's tab20 (20 distinct colors)
base_colors = plt.get_cmap("tab20").colors  

# Option B: seaborn "hls" or "husl" palette (works for any number of categories)
# base_colors = sns.color_palette("husl", len(methods))

# 4) assign each method a color
colormap = {m: base_colors[i % len(base_colors)] for i, m in enumerate(methods)}

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-mom-ns-adam-beta-0", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/dap-mom"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

plot_tuned_curves(outputs, colormap, outfilename="dap-mom-curves", val=False, wallclock=True)

# %%
output_dir = "gptopt/outputs/finewebmini_baseline"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

plot_tuned_curves(outputs, colormap, outfilename="finewebmini-baseline-curves", val=False, wallclock=True)

# %%
output_dir = "gptopt/outputs/dap-mom-ns-noln"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-mom-ns-noln", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/finewebmini-ema0.5"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="finewebmini-ema0.5", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/dap-mom-rcond"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a distinct qualitative colormap (tab20, Set3, or seaborn color_palette)
# Option A: matplotlib's tab20 (20 distinct colors)
base_colors = plt.get_cmap("tab20").colors  

# Option B: seaborn "hls" or "husl" palette (works for any number of categories)
# base_colors = sns.color_palette("husl", len(methods))

# 4) assign each method a color
colormap = {m: base_colors[i % len(base_colors)] for i, m in enumerate(methods)}


# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-mom-rcond", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/dap-mom"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a distinct qualitative colormap (tab20, Set3, or seaborn color_palette)
# Option A: matplotlib's tab20 (20 distinct colors)
base_colors = plt.get_cmap("tab20").colors  

# Option B: seaborn "hls" or "husl" palette (works for any number of categories)
# base_colors = sns.color_palette("husl", len(methods))

# 4) assign each method a color
colormap = {m: base_colors[i % len(base_colors)] for i, m in enumerate(methods)}


# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-mom", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/dap-mom-ns-decay"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap-mom-ns-decay", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/dap"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="dap", val=True)
plt.show()

# %%
output_dir = "gptopt/outputs/finewebmini_baseline"
outputs = load_outputs(output_dir)

# 2) extract unique method names (before the "-lr-" suffix)
methods = sorted({ output['name'].split('-lr-')[0] for output in outputs })

# 3) get a discrete viridis with len(methods) colors
base_cmap = plt.get_cmap('viridis', len(methods))

# 4) map each method name → RGBA tuple
colormap = { m: base_cmap(i) for i, m in enumerate(methods) }

# 5) plot
plot_final_loss_vs_lr(outputs, colormap, outfilename="finewebmini_baseline", val=True)
plt.show()
